# %% [markdown]
# ## **Analyzing the JSON lines (jsonl)Dataset using Pandas-Profiling Library by installing jsonlines**

# %%
import pandas as pd

# %% [markdown]
# ### **Installing json lines library**

# %%
# !pip install jsonlines

# %%
import jsonlines

# %% [markdown]
# ### **Reading Json lines files**

# %%
with jsonlines.open('/content/data.jsonl') as reader:
    data = [line for line in reader]

# %% [markdown]
# ### **Converting jsonl file into dataframe**

# %%
data_update=pd.DataFrame(data)

# %%
data_update
# Out:
#                                                  response
# 0       "What is the most significant event that has i...
# 1       If you could travel anywhere in the world, whe...
# 2       "If you could travel anywhere in the world and...
# 3       If you could travel back in time, what histori...
# 4       If you could travel back in time, what histori...
# ...                                                   ...
# 173569  "Imagine you have the ability to redesign your...
# 173570  What are some ways you can reduce your carbon ...
# 173571  If you could travel back in time to any moment...
# 173572  Think of a creative way to reimagine a classic...
# 173573  "If you could travel back in time, what histor...
#
# [173574 rows x 1 columns]

# %% [markdown]
# ### **Installing pandas-profiling library**

# %%
# !pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.8/357.8 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 32.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 31.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 41.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=0a01ded458c601db64abcb3e561f4ffcddd944de34dddfcc15d25b014e510a1e
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: seaborn
# ...

# %%
# !pip install ydata-profiling #Since pandas-profiling is updated as ydata-profiling

# %% [markdown]
# ### **Converting the dataset fie into HTML file to view the output**

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(data_update)
prof.to_file(output_file='output3.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
