# %% [markdown]
# ## **Basic steps to understand the Data**

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/train.csv')

# %% [markdown]
# **1. How big is the data?**

# %%
data.shape  #Generally to know the dimension of the data
# Out:
# (891, 12)

# %% [markdown]
# **2. How does the data look like?**

# %%
data.head() #It gives the first 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sample(4) #It gives ramdom samples which is the better opt.
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 601          602         0       3     Slabenoff, Mr. Petco    male   NaN
# 702          703         0       3    Barbara, Miss. Saiide  female  18.0
# 327          328         1       2  Ball, Mrs. (Ada E Hall)  female  36.0
# 387          388         1       2         Buss, Miss. Kate  female  36.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 601      0      0  349214   7.8958   NaN        S
# 702      0      1    2691  14.4542   NaN        C
# 327      0      0   28551  13.0000     D        S
# 387      0      0   27849  13.0000   NaN        S

# %% [markdown]
# **3. What is the data type of columns in the dataset?**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **4. Are there any missing values?**

# %%
data.isnull().sum() #this gives the no. of missing values as per the rows
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **5. How does the data look mathemativcally?**

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **6. Are there any duplicate values or the rows?**

# %%
data.duplicated().sum() #Here output is zero it means there are no duplicate values
# Out:
# 0

# %% [markdown]
# **7. To know the correlation between Columns**

# %%
data.corr() #It gives correlation within each row
# Out:
# <ipython-input-12-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
data.corr()['Pclass'] #to know the correlation for each column
# Out:
# <ipython-input-13-5dd5f27bceb3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()['Pclass'] #to know the correlation for each column
# PassengerId   -0.035144
# Survived      -0.338481
# Pclass         1.000000
# Age           -0.369226
# SibSp          0.083081
# Parch          0.018443
# Fare          -0.549500
# Name: Pclass, dtype: float64
