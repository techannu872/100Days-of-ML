# %% [markdown]
# ## **Creating or Fetching the Dataset From API**

# %%
import pandas as pd
import requests

# %%
#importing the url using API key
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
#importing the required columns
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     112.833
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      99.169
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      69.292
# 3  The true story of how businessman Oskar Schind...   1993-12-15      54.910
# 4  The defense and the prosecution have rested an...   1957-04-10      49.244
#
#    vote_average  vote_count
# 0         8.712       25510
# 1         8.707       19405
# 2         8.591       11705
# 3         8.572       15090
# 4         8.548        8013

# %%
#Creating an empty dataframe to append upcoming requests
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Applying the loop for upcoming data
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-8-bfe80980b1c6>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-8-bfe80980b1c6>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-8-bfe80980b1c6>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-8-bfe80980b1c6>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
#Showing the imported data
df
# Out:
#           id                                     title  \
# 0        278                  The Shawshank Redemption
# 1        238                             The Godfather
# 2        240                     The Godfather Part II
# 3        424                          Schindler's List
# 4        389                              12 Angry Men
# ...      ...                                       ...
# 8555   11237  Anacondas: The Hunt for the Blood Orchid
# 8556    8944                        What Just Happened
# 8557  535581                        The Dead Don't Die
# 8558  516043                    Here Come the Teachers
# 8559  512025         There's Someone Inside Your House
#
#                                                overview release_date  \
# 0     Framed in the 1940s for the double murder of h...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
#Converting the imported data into CSV file
df.to_csv('movies_record')
