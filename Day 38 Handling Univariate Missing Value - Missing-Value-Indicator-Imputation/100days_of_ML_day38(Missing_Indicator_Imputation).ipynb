# %% [markdown]
# ### **Handling Univariate Missing Values using Missing-Indicator-Imputation**

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.impute import MissingIndicator,SimpleImputer

# %%
data = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])

# %%
data.sample(10)
# Out:
#      Survived   Age     Fare
# 114         0  17.0  14.4583
# 570         1  62.0  10.5000
# 18          0  31.0  18.0000
# 151         1  22.0  66.6000
# 382         0  32.0   7.9250
# 765         1  51.0  77.9583
# 781         1  17.0  57.0000
# 278         0   7.0  29.1250
# 300         1   NaN   7.7500
# 301         1   NaN  23.2500

# %%
X = data.drop(columns=['Survived'])
y = data['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.tail()
# Out:
#       Age      Fare
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250

# %% [markdown]
# #### **Calling Simple Imputer Function**

# %%
si = SimpleImputer()
X_train_trf = si.fit_transform(X_train)
X_test_trf = si.transform(X_test)

# %%
X_train_trf
# Out:
# array([[ 40.        ,  27.7208    ],
#        [  4.        ,  16.7       ],
#        [ 47.        ,   9.        ],
#        ...,
#        [ 71.        ,  49.5042    ],
#        [ 29.78590426, 221.7792    ],
#        [ 29.78590426,  25.925     ]])

# %% [markdown]
# #### **Checking Accuracy by Applying Missing-Indicator-Imputation**

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf,y_train)

y_pred = clf.predict(X_test_trf)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6145251396648045

# %%
mi = MissingIndicator()

mi.fit(X_train)
# Out:
# MissingIndicator()

# %%
mi.features_
# Out:
# array([0])

# %%
X_train_missing = mi.transform(X_train)

# %%
X_train_missing
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
X_test_missing = mi.transform(X_test)

# %%
X_test_missing
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %% [markdown]
# #### **Checking accuracy by applying only Simple Imputer**

# %%
X_train['Age_NA'] = X_train_missing

# %%
X_test
# Out:
#       Age     Fare
# 707  42.0  26.2875
# 37   21.0   8.0500
# 615  24.0  65.0000
# 169  28.0  56.4958
# 68   17.0   7.9250
# ..    ...      ...
# 89   24.0   8.0500
# 80   22.0   9.0000
# 846   NaN  69.5500
# 870  26.0   7.8958
# 251  29.0  10.4625
#
# [179 rows x 2 columns]

# %%
X_test['Age_NA'] = X_test_missing

# %%
X_train
# Out:
#       Age      Fare  Age_NA
# 30   40.0   27.7208   False
# 10    4.0   16.7000   False
# 873  47.0    9.0000   False
# 182   9.0   31.3875   False
# 876  20.0    9.8458   False
# ..    ...       ...     ...
# 534  30.0    8.6625   False
# 584   NaN    8.7125    True
# 493  71.0   49.5042   False
# 527   NaN  221.7792    True
# 168   NaN   25.9250    True
#
# [712 rows x 3 columns]

# %%
si = SimpleImputer()

X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173

# %% [markdown]
# #### **Checking Accuracy by applying Missing-Indicator-Imputation using Simple Imputer**

# %%
si = SimpleImputer(add_indicator=True)

# %%
X_train = si.fit_transform(X_train)

# %%
X_test = si.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train_trf2,y_train)

y_pred = clf.predict(X_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6312849162011173
